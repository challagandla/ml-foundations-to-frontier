# %% [markdown]
# # 00 · Orientation
#
# Companion notebook to [`index.html`](index.html) in this folder.
#
# This one's short: its only job is to confirm your Python environment is
# ready before Module 01 needs `numpy` and `matplotlib`, and to show you the
# one line every later notebook starts with.

# %% [markdown]
# ## 1. Environment check
#
# If you haven't yet, set up the environment from the project root:
#
# ```
# python -m venv .venv
# .venv\Scripts\activate
# pip install -r requirements.txt
# ```
#
# Then run the cell below. It should print version numbers with no errors.

# %%
import sys
print('Python:', sys.version)

import numpy as np
print('numpy:', np.__version__)

import pandas as pd
print('pandas:', pd.__version__)

import matplotlib
print('matplotlib:', matplotlib.__version__)

import sklearn
print('scikit-learn:', sklearn.__version__)

print('\nAll good -- you are ready for Module 01.')

# %% [markdown]
# ## 2. The line every later notebook starts with
#
# Every module notebook imports the shared course helpers the same way. Run
# this cell -- if it prints without error, you're set for the whole course.

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path('../../shared/notebook_utils').resolve()))
from course_utils import set_style, load_dataset, rng, DATA_DIR

set_style()
print('Shared course utils loaded. Data directory:', DATA_DIR)

# %% [markdown]
# ## 3. A one-cell taste of what's coming
#
# Not an exercise -- just a preview so Module 01 doesn't feel like your first
# time seeing this kind of code.

# %%
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 200)
y = x ** 2

plt.plot(x, y)
plt.title('A preview -- see you in Module 01')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## Summary & self-assessment
#
# - [ ] My environment prints version numbers with no errors
# - [ ] The shared `course_utils` import works
# - [ ] I understand the index.html / notebook.ipynb split
#
# Next: `../01-linear-algebra/index.html`
