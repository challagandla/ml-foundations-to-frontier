# %% [markdown]
# # 01 · Python I: Values, Variables & Control Flow
#
# Companion notebook to [`index.html`](index.html) in this folder.
#
# **Objectives:**
# - Trace a short Python program by hand, line by line
# - Use int/float/str/bool values and variables correctly
# - Steer a program with if/elif/else, while, and for loops
#
# **How to use this notebook:** click a code cell, press `Shift+Enter` to run it.
# Edit anything, re-run, break things on purpose — a notebook is a sandbox, and
# error messages are feedback, not failure.

# %% [markdown]
# ## Values, types, and variables
#
# Run this cell, then change the values and run it again.

# %%
answer = 42            # int
pi = 3.14159           # float
name = "Ada"           # str
is_learning = True     # bool

print(answer, type(answer))
print(pi, type(pi))
print(name, type(name))
print(is_learning, type(is_learning))

# %%
# f-strings: put variables inside text with {curly braces}
price = 120
discount = 0.25
final = price * (1 - discount)
print(f"Original: {price}, after {discount:.0%} off: {final}")

# %% [markdown]
# ## The predict-the-output game
#
# For each cell below: **write your prediction as a comment first**, THEN run the
# cell. The point is to catch differences between your mental model and Python's
# actual behavior — a wrong prediction here is the most valuable thing in this
# notebook.

# %%
# My prediction: 
a = 7
b = a
a = 9
print(b)

# %%
# My prediction: 
print(7 / 2)
print(7 // 2)
print(7 % 2)

# %%
# My prediction: 
total = 0
for n in range(5):
    total = total + n
print(total)

# %%
# My prediction:  (careful -- this one is from the deep-dive section)
print(0.1 + 0.2)
print(0.1 + 0.2 == 0.3)

# %% [markdown]
# ## Guided exercises
#
# Replace each `...` with working code. Hints are in the comments; solutions are
# at the bottom — but wrestle with each one for a few minutes first.

# %%
# TODO 1: Even or odd
# Print "even" if x is even, "odd" otherwise.
# hint: x % 2 == 0 is True exactly for even numbers
x = 17
...

# %%
# TODO 2: Sum of squares
# Compute 1^2 + 2^2 + ... + 10^2 with a for loop. (Answer should be 385.)
# hint: n ** 2 is n squared; remember range's stop value is excluded
total = 0
...
print(total)

# %%
# TODO 3: Countdown (a while loop)
# Print 5, 4, 3, 2, 1, Liftoff! using a while loop.
# hint: start with n = 5; loop while n > 0; decrease n inside the loop --
# forgetting that last part is how infinite loops happen (Kernel > Interrupt saves you)
n = 5
...

# %%
# TODO 4: FizzBuzz -- the classic
# For numbers 1 to 20: print "FizzBuzz" if divisible by both 3 and 5,
# "Fizz" if only by 3, "Buzz" if only by 5, otherwise the number itself.
# hint: check the "both" case FIRST -- order of branches matters (why?)
for n in range(1, 21):
    ...

# %% [markdown]
# ## Challenge (optional)
#
# **Collatz steps.** Start from any positive integer `n`. Repeatedly: if `n` is
# even, halve it; if odd, replace it with `3*n + 1`. Count how many steps it takes
# to reach 1. For `n = 27` the answer is 111. (Whether *every* starting number
# reaches 1 is a famous unsolved problem — your loop will still terminate for any
# number you'll realistically try.)

# %%
n = 27
steps = 0
# your loop here

# %% [markdown]
# ## Solutions
#
# **TODO 1:**
# ```python
# if x % 2 == 0:
#     print("even")
# else:
#     print("odd")
# ```
#
# **TODO 2:**
# ```python
# total = 0
# for n in range(1, 11):
#     total = total + n ** 2
# print(total)  # 385
# ```
#
# **TODO 3:**
# ```python
# n = 5
# while n > 0:
#     print(n)
#     n = n - 1
# print("Liftoff!")
# ```
#
# **TODO 4:** (the `n % 15 == 0` check must come first — if you check `% 3` first,
# 15 would print "Fizz" and never reach the FizzBuzz branch)
# ```python
# for n in range(1, 21):
#     if n % 15 == 0:
#         print("FizzBuzz")
#     elif n % 3 == 0:
#         print("Fizz")
#     elif n % 5 == 0:
#         print("Buzz")
#     else:
#         print(n)
# ```
#
# **Challenge:**
# ```python
# n = 27
# steps = 0
# while n != 1:
#     if n % 2 == 0:
#         n = n // 2
#     else:
#         n = 3 * n + 1
#     steps = steps + 1
# print(steps)  # 111
# ```

# %% [markdown]
# ## Summary & self-assessment
#
# - [ ] I can trace a short program on paper: next line + variable values
# - [ ] I predicted at least 3 of the 4 predict-the-output cells correctly
# - [ ] My FizzBuzz works, and I can explain why branch order matters
# - [ ] I got the self-check quiz right on the HTML page
#
# Next: `../02-python-functions-data-structures/index.html`
