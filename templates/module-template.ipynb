# %% [markdown]
# # NN · Module Title
#
# Companion notebook to [`index.html`](index.html) in this folder.
#
# **Objectives** (mirror the HTML page's objectives list):
# - Objective one
# - Objective two
#
# This is the reference notebook template — copy it into a module folder and
# fill in each section below. Keep the section order across modules.

# %% [markdown]
# ## Setup

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path('../../shared/notebook_utils').resolve()))
from course_utils import set_style, load_dataset, rng, DATA_DIR

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

set_style()

# %% [markdown]
# ## Reproduce the demo
#
# Rebuild a small runnable version of the HTML page's interactive demo here,
# so the intuition transfers from "drag a slider" to "change a variable in code".

# %%
# Reproduce the demo in code

# %% [markdown]
# ## Guided exercises
#
# Cells below have `# TODO` markers. Fill them in; hints are in comments.

# %%
# TODO: exercise 1
# hint: ...

# %% [markdown]
# ## From scratch vs. library
#
# Implement the core algorithm manually first (ties back to the HTML page's
# math deep-dive), then compare against the scikit-learn / PyTorch equivalent.

# %%
# From-scratch implementation

# %%
# Library equivalent, for comparison

# %% [markdown]
# ## Applied
#
# Run the concept against a real (or realistic synthetic) dataset from `shared/data`.

# %%
# df = load_dataset('...')

# %% [markdown]
# ## Challenge (optional)
#
# A harder extension for if you want to go further.

# %% [markdown]
# ## Solutions
#
# Solutions to the guided exercises above, collapsed by convention: kept in
# this same notebook, below a clear `## Solutions` heading, so there's one
# file per module rather than a separate solutions notebook to keep in sync.

# %% [markdown]
# ## Summary & self-assessment
#
# - [ ] I can restate this module's objectives in my own words
# - [ ] I completed the guided exercises without looking at the solutions
# - [ ] I got the self-check quiz right on the HTML page
#
# Next: `../NN-next-slug/index.html`
